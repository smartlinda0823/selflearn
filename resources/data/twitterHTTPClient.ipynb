# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
import socket
import json
import datetime
import credentials

# %%
# credentials
ACCESS_TOKEN = credentials.ACCESS_TOKEN     # access token
ACCESS_SECRET = credentials.ACCESS_SECRET    # access token secret
CONSUMER_KEY = credentials.CONSUMER_KEY     # API key
CONSUMER_SECRET = credentials.CONSUMER_SECRET   # API secret key

# %%
# the tags to track
tags = ['#', 'covid-19', 'stayathome', 'hero', 'nursing']

# %%
class TweetsListener(StreamListener):
    """
    tweets listener object
    """
    def __init__(self, csocket):
        self.client_socket = csocket
    def on_data(self, data):
        try:
            msg = json.loads( data )
            print('TEXT:{}\n'.format(msg['text']))
            self.client_socket.send( msg['text'].encode('utf-8') )
            return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
            return False
        # return True
    def on_error(self, status):
        print(status)
        return False

# %%
def sendData(c_socket, tags):
    """
    send data to socket
    """
    auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
    api = tweepy.API(auth)
    twitter_stream = tweepy.Stream(auth = api.auth, listener = TweetsListener(c_socket))
    twitter_stream.filter(track=tags,languages=['en'])

# %%
class twitter_client:
    def __init__(self, TCP_IP, TCP_PORT):
      self.s = s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      self.s.bind((TCP_IP, TCP_PORT))

    def run_client(self, tags):
      try:
        self.s.listen(1)
        while True:
          print("Waiting for TCP connection...")
          conn, addr = self.s.accept()
          print("Connected... Starting getting tweets.")
          sendData(conn,tags)
          conn.close()
      except KeyboardInterrupt:
        exit

# %%
    client = twitter_client("localhost", 9001)
    client.run_client(tags)
# Out:
# Waiting for TCP connection...
# Connected... Starting getting tweets.
# TEXT:RT @UNITEDWEDREAM: It has been confirmed now that one person has died from COVID-19 in ICE custody.
#
# Rest in power, Carlos Ernesto Escobar…
#
# TEXT:RT @gaslinezoneaba: Evacuation of almajiri from north may cost damage in the eastern region if adequate security is not build-up. Biafrans…
#
# TEXT:RT @nobarkingart: #Banksy paying tribute to the The new super hero in our time. #thankyouNHS https://t.co/dpuiR5LRki
#
# TEXT:RT @MayorOfLA: Testing is critical to slowing the spread of COVID-19 — and any rumors that kids can be taken away from parents or guardians…
#
# TEXT:RT @DiazCanelB: Cuba in favorable scenario of the  COVID-19 evolution curve, but irresponsibility must be avoided.
# #CubaSalvaVidas
# https:…
#
# TEXT:RT @ChuckCallesto: BREAKING NOW:  Texas Lt. Gov. @DanPatrick covers jailed hairstylists’ 7k dollar fine for defying stay at home to feed he…
#
# ...
